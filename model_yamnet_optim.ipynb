# %%
import os
import sys
import logging
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import json
from datetime import datetime
from collections import Counter

# %%
# Custom stdout filter
class LogFilter:
    def __init__(self):
        self.terminal = sys.stdout
        
    def write(self, message):
        if not any(x in message for x in ['EGL', 'GL version', 'NVIDIA', 'Feedback manager']):
            self.terminal.write(message)
            
    def flush(self):
        self.terminal.flush()

sys.stdout = LogFilter()

# Set environment variables to suppress logs
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['MEDIAPIPE_DISABLE_LOG'] = '1'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'  # Explicitly set GPU

# Additionally redirect stderr
class StderrFilter:
    def __init__(self):
        self.terminal = sys.stderr
        
    def write(self, message):
        if not any(x in message for x in ['EGL', 'GL version', 'NVIDIA', 'Feedback manager', 'Successfully initialized']):
            self.terminal.write(message)
            
    def flush(self):
        self.terminal.flush()

sys.stderr = StderrFilter()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744140991.767322  104313 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744140991.771354  104313 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1744140991.781743  104313 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744140991.781755  104313 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744140991.781756  104313 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744140991.781757  104313 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading metadata...
# Total number of species: 206
# Preparing dataset...
# Extracting and caching features for 0 files...
# 0it [00:00, ?it/s]
# Feature extraction and caching complete!
# Preparing dataset...
# Preparing dataset...
# Preparing dataset...
# Extracting and caching features for 0 files...
# 0it [00:00, ?it/s]
# Feature extraction and caching complete!
# Preparing dataset...
# Finding files: 100%|##########| 28564/28564 [00:00<00:00, 28962.44it/s]
# Found 28564 valid files
# Class distribution:
#   grekis: 990 files
#   compau: 808 files
#   trokin: 787 files
#   roahaw: 709 files
#   banana: 610 files
#   ... and 201 more classes
# Training samples: 22851
# Validation samples: 5713
# Checking sample data...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1744141392.840973  104313 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744141392.886039  104463 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1744141392.898655  104469 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Features shape: torch.Size([521])
# Features min/max/mean: 0.0000/0.0000/0.0000
# Label: 104 (corresponds to: creoro1)
# I0000 00:00:1744141393.822945  104313 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744141393.846481  104470 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744141393.856970  104471 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744141394.394390  104313 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744141394.420983  104481 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744141394.425001  104482 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744141395.157559  104313 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744141395.186063  104489 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744141395.193578  104492 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744141395.329819  104313 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744141395.357776  104496 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744141395.364138  104497 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744141395.727720  104313 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744141395.756330  104503 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744141395.762114  104505 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744141396.206065  104313 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744141396.233814  104511 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744141396.239162  104512 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744141396.343595  104313 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744141396.370100  104518 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744141396.374110  104519 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744141396.507400  104313 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744141396.533853  104525 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744141396.538120  104528 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744141396.711688  104313 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744141396.737846  104532 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744141396.745796  104534 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Zero feature vectors in first 10 samples: 10
# Extracting and caching features for 28564 files...
#   0%|          | 0/28564 [00:00<?, ?it/s]I0000 00:00:1744141398.141065  104313 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744141398.169213  104539 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744141398.174832  104542 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   0%|          | 1/28564 [00:01<12:32:42,  1.58s/it]I0000 00:00:1744141399.601111  104313 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744141399.625076  104550 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744141399.630371  104551 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   0%|          | 2/28564 [00:03<11:57:46,  1.51s/it]I0000 00:00:1744141401.487840  104313 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744141401.510736  104557 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744141401.514092  104558 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   0%|          | 3/28564 [00:04<13:24:12,  1.69s/it]I0000 00:00:1744141403.141145  104313 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744141403.164507  104564 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744141403.173228  104565 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   0%|          | 4/28564 [00:06<13:16:04,  1.67s/it]I0000 00:00:1744141404.799823  104313 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744141404.822785  104575 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744141404.831433  104576 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   0%|          | 5/28564 [00:08<13:14:02,  1.67s/it]I0000 00:00:1744141406.231488  104313 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744141406.255996  104582 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744141406.259968  104583 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   0%|          | 6/28564 [00:09<12:33:27,  1.58s/it]I0000 00:00:1744141406.792918  104313 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744141406.814046  104589 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744
gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744141817.803957  108849 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744141817.809569  108852 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   2%|2         | 596/28564 [07:03<5:30:54,  1.41it/s]

# %%
# Custom stdout filter to suppress MediaPipe logs
class MediaPipeFilter:
    def __init__(self):
        self.terminal = sys.stdout
        
    def write(self, message):
        if not any(x in message for x in ['EGL', 'GL version', 'NVIDIA', 'Feedback manager']):
            self.terminal.write(message)
            
    def flush(self):
        self.terminal.flush()

sys.stdout = MediaPipeFilter()

# Set environment variables to suppress logging
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['MEDIAPIPE_DISABLE_LOG'] = '1'

# Disable all logging
logging.disable(logging.CRITICAL)

# %%
# Download YAMNet model
if not os.path.exists('yamnet.tflite'):
    print("Downloading YAMNet model...")
    import urllib.request
    urllib.request.urlretrieve('https://storage.googleapis.com/mediapipe-models/audio_classifier/yamnet/float32/1/yamnet.tflite', 'yamnet.tflite')

# Import MediaPipe
from mediapipe.tasks import python
from mediapipe.tasks.python import audio
from mediapipe.tasks.python.components import containers

# %%
# Define paths
base_dir = "/data/birdclef/birdclef-2025"
train_audio_dir = os.path.join(base_dir, "train_audio")
train_csv_path = os.path.join(base_dir, "train.csv")
taxonomy_path = os.path.join(base_dir, "taxonomy.csv")

# Create results directory
results_dir = 'training_results/yamnet_training_results'
os.makedirs(results_dir, exist_ok=True)

# Load metadata
print("Loading metadata...")
train_df = pd.read_csv(train_csv_path)
taxonomy_df = pd.read_csv(taxonomy_path)

# %%
# Create a mapping from primary_label to class index
unique_labels = train_df['primary_label'].unique()
label_to_idx = {label: idx for idx, label in enumerate(unique_labels)}
idx_to_label = {idx: label for label, idx in label_to_idx.items()}

print(f"Total number of species: {len(unique_labels)}")

# %%
# Function to load audio without librosa (to avoid numba dependency)
def load_audio_file(file_path, target_sr=16000):
    """Load audio file without using librosa"""
    import soundfile as sf
    
    try:
        # Load audio with soundfile
        audio_data, sr = sf.read(file_path)
        
        # Convert to mono if stereo
        if len(audio_data.shape) > 1:
            audio_data = audio_data.mean(axis=1)
        
        # Resample if needed (simple method)
        if sr != target_sr:
            # Simple resampling (not as good as librosa but works without numba)
            from scipy import signal
            duration = len(audio_data) / sr
            new_length = int(duration * target_sr)
            audio_data = signal.resample(audio_data, new_length)
        
        return audio_data, target_sr
    except Exception as e:
        print(f"Error loading {os.path.basename(file_path)}: {e}")
        return np.zeros(1000), target_sr  # Return short empty audio

# Global variables for error tracking
error_files = {}
processed_files = 0
successful_files = 0

# %%
# In your extract_yamnet_embeddings function:
def extract_yamnet_embeddings(audio_path):
    """Extract YAMNet embeddings directly instead of class scores."""
    try:
        # Load audio (same as before)
        audio_data, sample_rate = load_audio_file(audio_path, target_sr=16000)
        
        if len(audio_data) < 100:
            raise ValueError("Audio too short")
        
        # Import TensorFlow and YAMNet directly
        import tensorflow as tf
        import tensorflow_hub as hub
        
        # Load YAMNet model
        yamnet_model = hub.load('https://tfhub.dev/google/yamnet/1')
        
        # Get embeddings directly
        scores, embeddings, _ = yamnet_model(audio_data)
        
        # Average the embeddings across time segments
        # embeddings shape is [num_segments, 1024]
        mean_embedding = tf.reduce_mean(embeddings, axis=0).numpy()
        
        return mean_embedding  # Returns 1024-dimensional vector
        
    except Exception as e:
        print(f"Error processing {audio_path}: {e}")
        return np.zeros(1024)  # Return zeros with 1024 dimensions

# %%
def extract_and_cache_yamnet_features(file_paths, cache_dir='yamnet_features_cache'):
    """Extract YAMNet features and cache them to disk."""
    # Create cache directory if it doesn't exist
    os.makedirs(cache_dir, exist_ok=True)
    
    # Track progress
    print(f"Extracting and caching features for {len(file_paths)} files...")
    
    # Process files
    for file_path in tqdm(file_paths):
        # Create a unique cache filename based on the audio file path
        # Use a hash to create a consistent filename
        cache_filename = str(hash(file_path)) + '.npy'
        cache_path = os.path.join(cache_dir, cache_filename)
        
        # Skip if already cached
        if os.path.exists(cache_path):
            continue
        
        try:
            # Extract features using your existing function
            features = extract_yamnet_embeddings(file_path)
            
            # Save to disk
            np.save(cache_path, features)
        except Exception as e:
            print(f"Error processing {file_path}: {e}")
    
    print("Feature extraction and caching complete!")

# %%
class BirdCLEFDataset(Dataset):
    def __init__(self, file_paths, labels, cache_dir='yamnet_features_cache'):
        self.file_paths = file_paths
        self.labels = labels
        self.cache_dir = cache_dir
        
    def __len__(self):
        return len(self.file_paths)
    
    def __getitem__(self, idx):
        audio_path = self.file_paths[idx]
        label = self.labels[idx]
        
        # Create cache filename
        cache_filename = str(hash(audio_path)) + '.npy'
        cache_path = os.path.join(self.cache_dir, cache_filename)
        
        # Load cached features if available
        if os.path.exists(cache_path):
            features = np.load(cache_path)
        else:
            # Fall back to extraction if not cached
            features = extract_yamnet_embeddings(audio_path)
            
            # Save for future use
            os.makedirs(self.cache_dir, exist_ok=True)
            np.save(cache_path, features)
        
        return torch.tensor(features, dtype=torch.float32), torch.tensor(label, dtype=torch.long)

# Create a simple classifier model
class BirdCLEFClassifier(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(BirdCLEFClassifier, self).__init__()
        self.fc1 = nn.Linear(input_dim, 256)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(256, output_dim)
        
    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
# Prepare dataset
print("Preparing dataset...")
file_paths = []
labels = []

# Increase sample size
# sample_size = 500  # Adjust based on your needs
# sampled_df = train_df.sample(sample_size, random_state=42)
sampled_df = train_df

for _, row in tqdm(sampled_df.iterrows(), total=len(sampled_df), desc="Finding files"):
    species_id = row['primary_label']
    filename = row['filename']
    file_path = os.path.join(train_audio_dir, filename)
    
    if os.path.exists(file_path):
        file_paths.append(file_path)
        labels.append(label_to_idx[species_id])

print(f"Found {len(file_paths)} valid files")

# Filter out classes with too few samples
label_counts = Counter(labels)
print("Class distribution:")
for label, count in label_counts.most_common(5):
    print(f"  {idx_to_label[label]}: {count} files")
print(f"  ... and {len(label_counts) - 5} more classes")

# Split into train and validation sets
train_files, val_files, train_labels, val_labels = train_test_split(
    file_paths, labels, test_size=0.2, random_state=42
)

print(f"Training samples: {len(train_files)}")
print(f"Validation samples: {len(val_files)}")

# Create datasets and dataloaders
train_dataset = BirdCLEFDataset(train_files, train_labels)
val_dataset = BirdCLEFDataset(val_files, val_labels)

# Check a sample to verify data is loaded correctly
print("Checking sample data...")
features, label = train_dataset[0]
print(f"Features shape: {features.shape}")
print(f"Features min/max/mean: {features.min():.4f}/{features.max():.4f}/{features.mean():.4f}")
print(f"Label: {label} (corresponds to: {idx_to_label[label.item()]})")

# Check if all features are zeros
zero_features = 0
for i in range(min(10, len(train_dataset))):
    features, _ = train_dataset[i]
    if torch.all(features == 0):
        zero_features += 1
print(f"Zero feature vectors in first 10 samples: {zero_features}")


# Pre-extract and cache features (do this once before training)
extract_and_cache_yamnet_features(file_paths, cache_dir='yamnet_features_cache')

# Then create datasets using cached features
train_dataset = BirdCLEFDataset(train_files, train_labels, cache_dir='yamnet_features_cache')
val_dataset = BirdCLEFDataset(val_files, val_labels, cache_dir='yamnet_features_cache')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 58
#      54 print(f"Zero feature vectors in first 10 samples: {zero_features}")
#      57 # Pre-extract and cache features (do this once before training)
# ---> 58 extract_and_cache_yamnet_features(file_paths, cache_dir='yamnet_features_cache')
#      60 # Then create datasets using cached features
#      61 train_dataset = BirdCLEFDataset(train_files, train_labels, cache_dir='yamnet_features_cache')
#
# Cell In[12], line 22, in extract_and_cache_yamnet_features(file_paths, cache_dir)
#      18     continue
#      20 try:
#      21     # Extract features using your existing function
# ---> 22     features = extract_yamnet_embeddings(file_path)
#      24     # Save to disk
#      25     np.save(cache_path, features)
#
# Cell In[11], line 9, in extract_yamnet_embeddings(audio_path, max_segments)
#       5 processed_files += 1
#       7 try:
#       8     # Load and preprocess audio
# ----> 9     audio_data, sample_rate = load_audio_file(audio_path, target_sr=16000)
#      11     if len(audio_data) < 100:  # Skip very short or empty audio
#      12         raise ValueError("Audio too short")
#
# Cell In[10], line 20, in load_audio_file(file_path, target_sr)
#      18         duration = len(audio_data) / sr
#      19         new_length = int(duration * target_sr)
# ---> 20         audio_data = signal.resample(audio_data, new_length)
#      22     return audio_data, target_sr
#      23 except Exception as e:
#
# File ~/Desktop/birdclef2025/.venv/lib/python3.10/site-packages/scipy/signal/_signaltools.py:3458, in resample(x, num, t, axis, window, domain)
#    3455 if domain == 'time':
#    3456     # Forward transform
#    3457     if real_input:
# -> 3458         X = sp_fft.rfft(x, axis=axis)
#    3459     else:  # Full complex FFT
#    3460         X = sp_fft.fft(x, axis=axis)
#
# File ~/Desktop/birdclef2025/.venv/lib/python3.10/site-packages/scipy/fft/_backend.py:28, in _ScipyBackend.__ua_function__(method, args, kwargs)
#      26 if fn is None:
#      27     return NotImplemented
# ---> 28 return fn(*args, **kwargs)
#
# File ~/Desktop/birdclef2025/.venv/lib/python3.10/site-packages/scipy/fft/_basic_backend.py:91, in rfft(x, n, axis, norm, overwrite_x, workers, plan)
#      89 def rfft(x, n=None, axis=-1, norm=None,
#      90          overwrite_x=False, workers=None, *, plan=None):
# ---> 91     return _execute_1D('rfft', _pocketfft.rfft, x, n=n, axis=axis, norm=norm,
#      92                        overwrite_x=overwrite_x, workers=workers, plan=plan)
#
# File ~/Desktop/birdclef2025/.venv/lib/python3.10/site-packages/scipy/fft/_basic_backend.py:32, in _execute_1D(func_str, pocketfft_func, x, n, axis, norm, overwrite_x, workers, plan)
#      30 if is_numpy(xp):
#      31     x = np.asarray(x)
# ---> 32     return pocketfft_func(x, n=n, axis=axis, norm=norm,
#      33                           overwrite_x=overwrite_x, workers=workers, plan=plan)
#      35 norm = _validate_fft_args(workers, plan, norm)
#      36 if hasattr(xp, 'fft'):
#
# File ~/Desktop/birdclef2025/.venv/lib/python3.10/site-packages/scipy/fft/_pocketfft/basic.py:61, in r2c(forward, x, n, axis, norm, overwrite_x, workers, plan)
#      58     raise ValueError(f"invalid number of data points ({tmp.shape[axis]}) specified")
#      60 # Note: overwrite_x is not utilised
# ---> 61 return pfft.r2c(tmp, (axis,), forward, norm, None, workers)
#
# KeyboardInterrupt:

# %%
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

# Initialize model, loss function, and optimizer
input_dim = 1024  # YAMNet has 521 classes
output_dim = len(unique_labels)

model = BirdCLEFClassifier(input_dim=1024, hidden_dim=512, output_dim=len(unique_labels))
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)  # Higher learning rate

# Initialize results tracking
results = {
    'epochs': [],
    'train_loss': [],
    'val_loss': [],
    'accuracy': [],
    'timestamp': []
}

# %%
# Training loop
num_epochs = 20  # Increase epochs
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

model.to(device)

print("\nStarting training...")
for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    
    # Training loop with less verbose progress bar
    for batch_idx, (features, labels) in enumerate(tqdm(train_loader, 
                                                       desc=f"Epoch {epoch+1}/{num_epochs}",
                                                       leave=False, ncols=80)):
        features, labels = features.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(features)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        
        # Print diagnostic info for first few batches
        if epoch == 0 and batch_idx < 3:
            print(f"\nDiagnostic - Batch {batch_idx}:")
            print(f"Features stats: min={features.min().item():.4f}, max={features.max().item():.4f}")
            print(f"Outputs: {outputs[0][:5].tolist()}")  # First 5 logits of first sample
            print(f"Label counts in batch: {torch.bincount(labels, minlength=5)[:5]}")
    
    # Validation
    model.eval()
    val_loss = 0.0
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        for features, labels in val_loader:
            features, labels = features.to(device), labels.to(device)
            outputs = model(features)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            
            # Get predicted class
            probs = torch.softmax(outputs, dim=1)
            _, preds = torch.max(probs, 1)
            
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    # Calculate metrics
    train_loss /= len(train_loader)
    val_loss /= len(val_loader)
    
    # Direct calculation of accuracy
    correct = sum(1 for x, y in zip(all_preds, all_labels) if x == y)
    total = len(all_labels)
    accuracy = correct / total if total > 0 else 0
    
    # Store results
    results['epochs'].append(epoch + 1)
    results['train_loss'].append(float(train_loss))
    results['val_loss'].append(float(val_loss))
    results['accuracy'].append(float(accuracy))
    results['timestamp'].append(datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    
    # Print progress
    print(f"Epoch {epoch+1}/{num_epochs}: Train Loss={train_loss:.4f}, Val Loss={val_loss:.4f}, Accuracy={accuracy:.4f}, Correct={correct}/{total}")
    
    # Print prediction distribution
    pred_counts = Counter(all_preds)
    print(f"Prediction distribution: {len(pred_counts)} classes predicted")
    if len(pred_counts) < 5:
        print("WARNING: Model is only predicting a few classes!")
        for pred, count in pred_counts.most_common():
            print(f"  Class {idx_to_label[pred]}: {count} predictions ({count/len(all_preds)*100:.1f}%)")
    
    # Save results every 5 epochs
    if (epoch + 1) % 5 == 0 or epoch == num_epochs - 1:
        # Save results to JSON
        results_file = os.path.join(results_dir, f'results_epoch_{epoch+1}.json')
        with open(results_file, 'w') as f:
            json.dump(results, f, indent=4)
        
        # Save model checkpoint
        model_file = os.path.join(results_dir, f'model_epoch_{epoch+1}.pt')
        torch.save({
            'epoch': epoch + 1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'train_loss': train_loss,
            'val_loss': val_loss,
            'accuracy': accuracy
        }, model_file)
        
        print(f"Saved results and model checkpoint at epoch {epoch+1}")

print("Training complete!")
print(f"Processed {processed_files} files, {successful_files} successful ({successful_files/processed_files*100:.1f}%)")

# Print error summary
print("\nError Summary:")
for error_type, files in error_files.items():
    print(f"{error_type}: {len(files)} files. Examples: {', '.join(files[:3])}")
