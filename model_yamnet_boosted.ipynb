# %%
import os
import sys
import logging
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import json
from datetime import datetime
from collections import Counter
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
# Custom stdout filter to suppress MediaPipe logs
class MediaPipeFilter:
    def __init__(self):
        self.terminal = sys.stdout
        
    def write(self, message):
        if not any(x in message for x in ['EGL', 'GL version', 'NVIDIA', 'Feedback manager']):
            self.terminal.write(message)
            
    def flush(self):
        self.terminal.flush()

sys.stdout = MediaPipeFilter()

# Set environment variables to suppress logging
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['MEDIAPIPE_DISABLE_LOG'] = '1'

# Disable all logging
logging.disable(logging.CRITICAL)

# %%
# Download YAMNet model
if not os.path.exists('yamnet.tflite'):
    print("Downloading YAMNet model...")
    import urllib.request
    urllib.request.urlretrieve('https://storage.googleapis.com/mediapipe-models/audio_classifier/yamnet/float32/1/yamnet.tflite', 'yamnet.tflite')

# Import MediaPipe
from mediapipe.tasks import python
from mediapipe.tasks.python import audio
from mediapipe.tasks.python.components import containers

# %%
# Define paths
base_dir = "/data/birdclef/birdclef-2025"
train_audio_dir = os.path.join(base_dir, "train_audio")
train_csv_path = os.path.join(base_dir, "train.csv")
taxonomy_path = os.path.join(base_dir, "taxonomy.csv")

# Create results directory
results_dir = 'training_results/yamnet_training_results_boost_deeper'
os.makedirs(results_dir, exist_ok=True)

# Load metadata
print("Loading metadata...")
train_df = pd.read_csv(train_csv_path)
taxonomy_df = pd.read_csv(taxonomy_path)

# %%
# Create a mapping from primary_label to class index
unique_labels = train_df['primary_label'].unique()
label_to_idx = {label: idx for idx, label in enumerate(unique_labels)}
idx_to_label = {idx: label for label, idx in label_to_idx.items()}

print(f"Total number of species: {len(unique_labels)}")

# %%
# Function to load audio without librosa (to avoid numba dependency)
def load_audio_file(file_path, target_sr=16000):
    """Load audio file without using librosa"""
    import soundfile as sf
    
    try:
        # Load audio with soundfile
        audio_data, sr = sf.read(file_path)
        
        # Convert to mono if stereo
        if len(audio_data.shape) > 1:
            audio_data = audio_data.mean(axis=1)
        
        # Resample if needed (simple method)
        if sr != target_sr:
            # Simple resampling (not as good as librosa but works without numba)
            from scipy import signal
            duration = len(audio_data) / sr
            new_length = int(duration * target_sr)
            audio_data = signal.resample(audio_data, new_length)
        
        return audio_data, target_sr
    except Exception as e:
        print(f"Error loading {os.path.basename(file_path)}: {e}")
        return np.zeros(1000), target_sr  # Return short empty audio

# Global variables for error tracking
error_files = {}
processed_files = 0
successful_files = 0

# %%
# Function to extract YAMNet embeddings
def extract_yamnet_embeddings(audio_path, max_segments=10):
    """Extract embeddings from audio file using MediaPipe YAMNet."""
    global processed_files, successful_files
    processed_files += 1
    
    try:
        # Load and preprocess audio
        audio_data, sample_rate = load_audio_file(audio_path, target_sr=16000)
        
        if len(audio_data) < 100:  # Skip very short or empty audio
            raise ValueError("Audio too short")
        
        # Create classifier options
        base_options = python.BaseOptions(model_asset_path='yamnet.tflite')
        options = audio.AudioClassifierOptions(
            base_options=base_options,
            max_results=5,
            running_mode=audio.RunningMode.AUDIO_CLIPS
        )
        
        # Create the classifier
        with audio.AudioClassifier.create_from_options(options) as classifier:
            # Convert to AudioData format
            audio_data_obj = containers.AudioData.create_from_array(
                audio_data.astype(float), sample_rate)
            
            # Classify audio
            result = classifier.classify(audio_data_obj)
            
            # Handle different result structures
            features = np.zeros(521)  # YAMNet has 521 classes
            
            # Check if result is a list or has classifications attribute
            if hasattr(result, 'classifications'):
                classifications_list = result.classifications
            elif isinstance(result, list):
                classifications_list = result
            else:
                # If neither, return zeros
                return features
            
            # Process each classification
            all_segment_features = []
            for segment_result in classifications_list:
                segment_features = np.zeros(521)
                
                # Handle different segment_result structures
                categories = []
                if hasattr(segment_result, 'categories'):
                    categories = segment_result.categories
                elif hasattr(segment_result, 'classification_list'):
                    categories = segment_result.classification_list
                
                # Extract features from categories
                for i, category in enumerate(categories):
                    if i >= max_segments:
                        break
                    if hasattr(category, 'index'):
                        class_idx = int(category.index)
                    else:
                        class_idx = i  # Fallback
                    
                    if hasattr(category, 'score'):
                        score = category.score
                    else:
                        score = 0.1  # Fallback
                    
                    if 0 <= class_idx < 521:
                        segment_features[class_idx] = score
                
                all_segment_features.append(segment_features)
            
            # If we have multiple segments, average them
            if all_segment_features:
                features = np.mean(all_segment_features, axis=0)
            
            successful_files += 1
            return features
    except Exception as e:
        error_type = str(type(e).__name__)
        if error_type not in error_files:
            error_files[error_type] = []
        if len(error_files[error_type]) < 3:  # Collect at most 3 examples per error type
            error_files[error_type].append(os.path.basename(audio_path))
        return np.zeros(521)  # Return zeros if processing fails

# %%
# Create a custom dataset
class BirdCLEFDataset(Dataset):
    def __init__(self, file_paths, labels):
        self.file_paths = file_paths
        self.labels = labels
        self.cache = {}  # Cache features to avoid recomputing
        
    def __len__(self):
        return len(self.file_paths)
    
    def __getitem__(self, idx):
        audio_path = self.file_paths[idx]
        
        # Use cached features if available
        if audio_path in self.cache:
            features = self.cache[audio_path]
        else:
            features = extract_yamnet_embeddings(audio_path)
            self.cache[audio_path] = features
            
        label = self.labels[idx]
        return torch.tensor(features, dtype=torch.float32), torch.tensor(label, dtype=torch.long)

# Create a simple classifier model
class BirdCLEFClassifier(nn.Module):
    def __init__(self, input_dim, output_dim, dropout_rate=0.5):
        super(BirdCLEFClassifier, self).__init__()
        # First layer
        self.fc1 = nn.Linear(input_dim, 512)  # Wider first layer
        self.bn1 = nn.BatchNorm1d(512)
        self.leaky1 = nn.LeakyReLU(0.1)  # LeakyReLU with 0.1 negative slope
        self.dropout1 = nn.Dropout(dropout_rate)
        
        # Second layer
        self.fc2 = nn.Linear(512, 256)
        self.bn2 = nn.BatchNorm1d(256)
        self.leaky2 = nn.LeakyReLU(0.1)
        self.dropout2 = nn.Dropout(dropout_rate)
        
        # Third layer (the additional layer)
        self.fc3 = nn.Linear(256, 128)
        self.bn3 = nn.BatchNorm1d(128)
        self.leaky3 = nn.LeakyReLU(0.1)
        self.dropout3 = nn.Dropout(dropout_rate)
        
        # Output layer
        self.fc4 = nn.Linear(128, output_dim)
        
    def forward(self, x):
        # First layer
        x = self.fc1(x)
        x = self.bn1(x)
        x = self.leaky1(x)
        x = self.dropout1(x)
        
        # Second layer
        x = self.fc2(x)
        x = self.bn2(x)
        x = self.leaky2(x)
        x = self.dropout2(x)
        
        # Third layer
        x = self.fc3(x)
        x = self.bn3(x)
        x = self.leaky3(x)
        x = self.dropout3(x)
        
        # Output layer
        x = self.fc4(x)
        return x
        
# Prepare dataset
print("Preparing dataset...")
file_paths = []
labels = []

# Increase sample size
# sample_size = 500  # Adjust based on your needs
# sampled_df = train_df.sample(sample_size, random_state=42)
sampled_df = train_df

# %%
for _, row in tqdm(sampled_df.iterrows(), total=len(sampled_df), desc="Finding files"):
    species_id = row['primary_label']
    filename = row['filename']
    file_path = os.path.join(train_audio_dir, filename)
    
    if os.path.exists(file_path):
        file_paths.append(file_path)
        labels.append(label_to_idx[species_id])

print(f"Found {len(file_paths)} valid files")

# Filter out classes with too few samples
label_counts = Counter(labels)
print("Class distribution:")
for label, count in label_counts.most_common(5):
    print(f"  {idx_to_label[label]}: {count} files")
print(f"  ... and {len(label_counts) - 5} more classes")
# Out:
# Finding files: 100%|██████████| 28564/28564 [00:00<00:00, 28748.42it/s]

# %%
# Split into train and validation sets
train_files, val_files, train_labels, val_labels = train_test_split(
    file_paths, labels, test_size=0.2, random_state=42
)

print(f"Training samples: {len(train_files)}")
print(f"Validation samples: {len(val_files)}")

# %%
# Create datasets and dataloaders
train_dataset = BirdCLEFDataset(train_files, train_labels)
val_dataset = BirdCLEFDataset(val_files, val_labels)

# Check a sample to verify data is loaded correctly
print("Checking sample data...")
features, label = train_dataset[0]
print(f"Features shape: {features.shape}")
print(f"Features min/max/mean: {features.min():.4f}/{features.max():.4f}/{features.mean():.4f}")
print(f"Label: {label} (corresponds to: {idx_to_label[label.item()]})")
# Out:
# I0000 00:00:1744082131.131059    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082131.168631    9666 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082131.174793    9669 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
# Check if all features are zeros
zero_features = 0
for i in range(min(10, len(train_dataset))):
    features, _ = train_dataset[i]
    if torch.all(features == 0):
        zero_features += 1
print(f"Zero feature vectors in first 10 samples: {zero_features}")
# Out:
# I0000 00:00:1744082136.706399    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082136.740631    9673 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082136.749369    9674 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082137.269345    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082137.299176    9680 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082137.304718    9683 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082138.013760    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082138.041850    9687 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082138.050538    9689 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082138.188054    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082138.214028    9694 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082138.220570    9696 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082138.582925    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082138.609085    9701 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082138.618006    9704 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082139.056064    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082139.083710    9708 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082139.092061    9709 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082139.202457    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082139.235711    9715 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082139.243948    9716 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082139.368768    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082139.397249    9722 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082139.402971    9725 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082139.575124    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082139.600556    9729 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082139.608365    9731 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

# Initialize model, loss function, and optimizer
input_dim = 521  # YAMNet has 521 classes
output_dim = len(unique_labels)


# Calculate class weights based on inverse frequency
class_counts = Counter(train_labels)
total_samples = len(train_labels)
class_weights = {cls: total_samples / (len(class_counts) * count) for cls, count in class_counts.items()}

# Convert to tensor
weight_tensor = torch.FloatTensor([class_weights.get(i, 1.0) for i in range(output_dim)]).to(device)

# Print some information about class weights
print("Class weight examples:")
for i in range(min(5, output_dim)):
    species_name = idx_to_label.get(i, "Unknown")
    weight = weight_tensor[i].item()
    count = class_counts.get(i, 0)
    print(f"  {species_name}: weight={weight:.2f} (count={count})")

model = BirdCLEFClassifier(input_dim, output_dim)
criterion = nn.CrossEntropyLoss(weight=weight_tensor)
optimizer = optim.Adam(model.parameters(), lr=0.01)  # Higher learning rate

# Initialize results tracking
results = {
    'epochs': [],
    'train_loss': [],
    'val_loss': [],
    'accuracy': [],
    'timestamp': []
}

# %%
# Training loop
num_epochs = 20  # Increase epochs


model.to(device)

print("\nStarting training...")
for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    
    # Training loop with less verbose progress bar
    for batch_idx, (features, labels) in enumerate(tqdm(train_loader, 
                            desc=f"Epoch {epoch+1}/{num_epochs}",
                            leave=False, ncols=80)):
        features, labels = features.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(features)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        
        # Print diagnostic info for first few batches
        if epoch == 0 and batch_idx < 3:
            print(f"\nDiagnostic - Batch {batch_idx}:")
            print(f"Features stats: min={features.min().item():.4f}, max={features.max().item():.4f}")
            print(f"Outputs: {outputs[0][:5].tolist()}")  # First 5 logits of first sample
            print(f"Label counts in batch: {torch.bincount(labels, minlength=5)[:5]}")
    
    # Validation
    model.eval()
    val_loss = 0.0
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        for features, labels in val_loader:
            features, labels = features.to(device), labels.to(device)
            outputs = model(features)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            
            # Get predicted class
            probs = torch.softmax(outputs, dim=1)
            _, preds = torch.max(probs, 1)
            
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    # Calculate metrics
    train_loss /= len(train_loader)
    val_loss /= len(val_loader)
    
    # Direct calculation of accuracy
    correct = sum(1 for x, y in zip(all_preds, all_labels) if x == y)
    total = len(all_labels)
    accuracy = correct / total if total > 0 else 0
    
    # Store results
    results['epochs'].append(epoch + 1)
    results['train_loss'].append(float(train_loss))
    results['val_loss'].append(float(val_loss))
    results['accuracy'].append(float(accuracy))
    results['timestamp'].append(datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    
    # Print progress
    print(f"Epoch {epoch+1}/{num_epochs}: Train Loss={train_loss:.4f}, Val Loss={val_loss:.4f}, Accuracy={accuracy:.4f}, Correct={correct}/{total}")
    
    # Print prediction distribution
    pred_counts = Counter(all_preds)
    print(f"Prediction distribution: {len(pred_counts)} classes predicted")
    if len(pred_counts) < 5:
        print("WARNING: Model is only predicting a few classes!")
        for pred, count in pred_counts.most_common():
            print(f"  Class {idx_to_label[pred]}: {count} predictions ({count/len(all_preds)*100:.1f}%)")
    
    # Save results every 5 epochs
    if (epoch + 1) % 5 == 0 or epoch == num_epochs - 1:
        # Save results to JSON
        results_file = os.path.join(results_dir, f'results_epoch_{epoch+1}.json')
        with open(results_file, 'w') as f:
            json.dump(results, f, indent=4)
        
        # Save model checkpoint
        model_file = os.path.join(results_dir, f'model_epoch_{epoch+1}.pt')
        torch.save({
            'epoch': epoch + 1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'train_loss': train_loss,
            'val_loss': val_loss,
            'accuracy': accuracy
        }, model_file)
        
        print(f"Saved results and model checkpoint at epoch {epoch+1}")

print("Training complete!")
# print(f"Processed {processed_files} files, {successful_files} successful ({successful_files/processed_files*100:.1f}%)")

# # Print error summary
# print("\nError Summary:")
# for error_type, files in error_files.items():
#     print(f"{error_type}: {len(files)} files. Examples: {', '.join(files[:3])}")


print("\nTraining boosted ensemble...")

# Extract features for all training samples
train_features = []
train_targets = []

print("Extracting features for boosting...")
for file_path, label in tqdm(zip(train_files, train_labels), total=len(train_files)):
    # Get features from our dataset cache if possible
    if file_path in train_dataset.cache:
        features = train_dataset.cache[file_path]
    else:
        features = extract_yamnet_embeddings(file_path)
        train_dataset.cache[file_path] = features
    
    train_features.append(features)
    train_targets.append(label)

train_features = np.array(train_features)
train_targets = np.array(train_targets)

# Do the same for validation set
val_features = []
val_targets = []

print("Extracting validation features...")
for file_path, label in tqdm(zip(val_files, val_labels), total=len(val_files)):
    if file_path in val_dataset.cache:
        features = val_dataset.cache[file_path]
    else:
        features = extract_yamnet_embeddings(file_path)
        val_dataset.cache[file_path] = features
    
    val_features.append(features)
    val_targets.append(label)

val_features = np.array(val_features)
val_targets = np.array(val_targets)

# Train AdaBoost ensemble
print("Training AdaBoost ensemble...")
base_estimator = DecisionTreeClassifier(max_depth=3)
boosted_model = AdaBoostClassifier(
    n_estimators=5,
    learning_rate=0.1,
    random_state=42
)

boosted_model.fit(train_features, train_targets)

# Evaluate boosted model
boost_preds = boosted_model.predict(val_features)
boost_accuracy = sum(1 for x, y in zip(boost_preds, val_targets) if x == y) / len(val_targets)
print(f"Boosted model accuracy: {boost_accuracy:.4f}")

# Save the boosted model
import pickle
with open(os.path.join(results_dir, 'boosted_model.pkl'), 'wb') as f:
    pickle.dump(boosted_model, f)
# Out:
# Epoch 1/20:   0%|                                      | 0/1429 [00:00<?, ?it/s]I0000 00:00:1744082157.646911    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082157.672139    9744 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082157.678592    9746 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082157.940656    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082157.969458    9751 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082157.975045    9753 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082158.226252    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082158.249501    9758 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082158.256386    9759 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082159.088453    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082159.114316    9765 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082159.119234    9771 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082159.577645    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082159.599948    9772 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082159.607108    9773 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082159.688393    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082159.716889    9779 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082159.721743    9785 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082159.857331    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082159.886214    9786 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082159.894081    9787 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082160.027949    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082160.055462    9793 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082160.060851    9794 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082160.123941    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082160.149232    9800 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082160.154098    9802 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082160.608998    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082160.633150    9807 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082160.641960    9808 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082163.640765    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082163.669728    9814 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082163.675391    9816 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082164.084222    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082164.106887    9821 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082164.112237    9823 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082164.334216    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082164.363268    9828 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082164.369334    9831 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082164.439115    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082164.461268    9835 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082164.464538    9836 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082165.559708    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082165.587461    9842 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082165.592860    9844 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082165.881583    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082165.904002    9849 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082165.912774    9851 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Epoch 1/20:   0%|                            | 1/1429 [00:08<3:23:42,  8.56s/it]I0000 00:00:1744082166.293078    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082166.324482    9857 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082166.330197    9859 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082166.561713    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082166.585854    9864 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082166.594531    9866 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082166.740086    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082166.769459    9871 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082166.775170    9873 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082167.489256    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082167.516671    9878 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082167.522018    9880 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082168.078594    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082168.105383    9885 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082168.110746    9886 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082168.202905    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082168.225676    9892 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082168.231236    9894 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082168.522554    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082168.545079    9899 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082168.548967    9900 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082169.863940    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082169.893787    9906 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082169.899722    9909 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082170.079311    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082170.108414    9913 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082170.114244    9915 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082170.462009    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082170.489331    9920 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082170.495047    9923 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082173.870115    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082173.901339    9927 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082173.906823    9929 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082174.369711    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082174.394846    9934 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082174.399880    9936 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082174.522171    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082174.550356    9941 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082174.555221    9942 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082174.695587    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082174.724006    9948 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082174.730282    9949 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082175.255316    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082175.280839    9955 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082175.286499    9957 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082175.411899    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082175.439200    9962 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082175.444133    9965 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Epoch 1/20:   0%|                            | 2/1429 [00:17<3:33:56,  9.00s/it]I0000 00:00:1744082175.853809    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082175.880804    9969 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082175.886194    9971 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082176.138396    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082176.163872    9976 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082176.168311    9977 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082176.792356    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082176.814936    9983 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082176.820900    9984 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082177.585922    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082177.609770    9990 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082177.615326    9991 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082178.220055    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082178.241898    9997 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082178.251356   10003 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082178.665116    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082178.687204   10004 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082178.695484   10006 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082178.958032    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082178.980479   10011 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082178.985993   10013 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082179.215211    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082179.237814   10018 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082179.245988   10020 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082180.114837    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082180.137714   10025 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082180.144046   10027 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082180.573286    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082180.597804   10032 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082180.601631   10033 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082180.703950    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082180.726051   10039 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082180.734820   10041 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082182.520728    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082182.552227   10046 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082182.558694   10049 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082183.129183    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082183.151894   10053 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082183.160640   10055 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082183.560908    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082183.583055   10060 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082183.591289   10061 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082184.009558    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082184.032369   10067 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082184.039951   10069 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082184.172162    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082184.194340   10074 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082184.201235   10075 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Epoch 1/20:   0%|                            | 3/1429 [00:26<3:31:09,  8.88s/it]I0000 00:00:1744082184.270962    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082184.300234   10081 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082184.305565   10083 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082184.367098    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082184.389118   10088 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082184.397400   10090 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082184.459894    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082184.483617   10095 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082184.490211   10098 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082184.611383    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082184.634011   10102 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082184.642223   10103 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082184.918013    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082184.940717   10109 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082184.949021   10111 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082185.084032    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082185.105992   10116 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082185.112244   10118 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082185.243146    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082185.265698   10123 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082185.269984   10126 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082185.630321    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082185.657082   10130 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082185.664554   10131 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082185.896952    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082185.919268   10137 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082185.926932   10139 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082186.175011    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082186.197314   10144 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082186.204770   10145 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082186.836034    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082186.859805   10151 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082186.865900   10152 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082187.272389    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082187.294818   10158 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082187.302140   10159 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082187.528772    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082187.551168   10165 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082187.557824   10167 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082187.737469    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082187.759729   10172 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082187.768263   10173 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082187.881466    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082187.905515   10179 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082187.912041   10180 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082187.978095    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082188.001833   10186 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082188.007291   10190 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Epoch 1/20:   0%|                            | 4/1429 [00:30<2:43:20,  6.88s/it]I0000 00:00:1744082188.129170    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082188.154613   10193 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082188.159926   10196 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082188.275352    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082188.304504   10200 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082188.309507   10202 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082188.542481    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082188.564642   10207 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082188.571587   10208 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082189.535727    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082189.559749   10214 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082189.566902   10215 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082189.727082    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082189.752637   10221 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082189.757404   10224 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082189.871911    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082189.895765   10228 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082189.902106   10230 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082190.766643    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082190.795434   10235 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082190.804428   10237 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082191.036228    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082191.058812   10242 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082191.067694   10243 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082192.406022    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082192.427969   10249 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082192.437212   10250 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082192.674828    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082192.697914   10256 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082192.703633   10259 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082193.401162    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082193.424941   10263 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082193.431442   10266 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082193.649281    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082193.673761   10270 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082193.682508   10272 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082194.140255    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082194.162700   10277 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082194.172874   10279 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082194.680527    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082194.702917   10284 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082194.708954   10287 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082195.107460    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082195.130348   10291 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082195.138987   10293 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082195.538293    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082195.560469   10298 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082195.566059   10299 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Epoch 1/20:   0%|                            | 5/1429 [00:38<2:49:28,  7.14s/it]I0000 00:00:1744082195.706780    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082195.729359   10305 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082195.735748   10306 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082195.832158    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082195.855946   10312 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082195.863732   10315 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082198.952916    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082198.976708   10319 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082198.980841   10322 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082199.634684    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082199.656838   10326 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082199.668587   10328 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082200.634902    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082200.657002   10333 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082200.664638   10334 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082200.852282    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082200.874760   10340 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082200.883507   10342 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082201.230729    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082201.252983   10347 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082201.261410   10350 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082201.407845    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082201.432346   10354 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082201.436853   10357 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082202.920706    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082202.943131   10361 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082202.952018   10362 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082203.218337    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082203.240809   10368 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082203.248731   10370 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082203.328588    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082203.350604   10375 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082203.358748   10377 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082203.513127    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082203.537094   10382 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082203.545483   10384 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082203.733051    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082203.762173   10389 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082203.768251   10391 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082203.999027    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082204.021064   10396 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082204.028253   10402 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082204.359466    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082204.381996   10403 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082204.390581   10405 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082204.480785    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082204.502580   10410 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082204.509539   10411 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Epoch 1/20:   0%|                            | 6/1429 [00:46<3:03:34,  7.74s/it]I0000 00:00:1744082204.580731    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082204.604420   10417 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082204.609766   10419 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082204.742291    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082204.770950   10424 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082204.779425   10425 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082204.945609    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082204.968143   10431 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082204.975446   10432 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082205.067815    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082205.090670   10438 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082205.098184   10444 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082205.322682    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082205.345130   10445 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082205.352219   10446 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082205.424060    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082205.454241   10452 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082205.460352   10454 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082205.903686    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082205.926276   10459 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082205.933452   10460 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082206.251141    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082206.278666   10466 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082206.284367   10469 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082210.455116    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082210.479025   10473 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082210.485846   10474 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082211.255495    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744082211.279620   10480 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744082211.287677   10481 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744082211.699047    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# ...
# W0000 00:00:1744084657.282558   53236 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084657.558205    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084657.582798   53242 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084657.588653   53244 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084657.732379    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084657.755302   53249 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084657.760889   53252 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084658.032710    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084658.064246   53256 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084658.071207   53258 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084658.679927    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084658.708854   53263 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084658.715012   53266 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084659.229430    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084659.252408   53270 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084659.256965   53271 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Epoch 1/20:  24%|██████▎                   | 348/1429 [41:41<1:47:21,  5.96s/it]I0000 00:00:1744084659.376474    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084659.401784   53277 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084659.408046   53279 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084659.529087    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084659.556041   53284 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084659.561772   53287 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084659.936016    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084659.959003   53291 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084659.968288   53293 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084660.295946    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084660.320722   53298 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084660.328141   53300 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084660.393432    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084660.416985   53305 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084660.422201   53308 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084660.559711    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084660.584276   53312 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084660.589484   53314 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084660.672071    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084660.695399   53319 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084660.700390   53320 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084660.807456    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084660.832099   53326 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084660.837514   53329 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084661.241905    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084661.264712   53333 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084661.273105   53334 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084661.772885    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084661.796062   53340 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084661.807689   53342 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084661.950839    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084661.973500   53347 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084661.983609   53348 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084662.055893    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084662.080806   53354 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084662.086874   53356 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084662.145255    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084662.168196   53361 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084662.176294   53363 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084662.253840    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084662.280030   53368 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084662.289562   53370 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084662.395890    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084662.418600   53375 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084662.427242   53377 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084662.629065    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084662.651865   53382 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084662.662791   53385 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Epoch 1/20:  24%|██████▎                   | 349/1429 [41:45<1:33:27,  5.19s/it]I0000 00:00:1744084663.142415    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084663.166102   53389 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084663.171745   53391 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084663.280968    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084663.306427   53396 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084663.312097   53398 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084663.352042    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084663.374308   53403 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084663.383150   53404 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084664.209926    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084664.234210   53410 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084664.239912   53411 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084664.507550    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084664.530546   53417 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084664.535279   53418 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084665.013860    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084665.038285   53424 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084665.045856   53426 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084665.195425    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084665.218295   53431 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084665.227125   53432 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084666.068454    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084666.091503   53438 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084666.099386   53440 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084666.392203    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084666.415252   53445 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084666.423772   53447 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084666.636906    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084666.659551   53452 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084666.667260   53454 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084666.762108    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084666.791585   53459 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084666.800330   53461 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084667.027109    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084667.056368   53466 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084667.062740   53469 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084667.845124    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084667.875563   53473 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084667.882561   53474 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1744084668.551503    9494 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1744084668.574484   53480 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 570.124.06), renderer: NVIDIA GeForce RTX 4070 Ti/PCIe/SSE2
# W0000 00:00:1744084668.583487   53482 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
